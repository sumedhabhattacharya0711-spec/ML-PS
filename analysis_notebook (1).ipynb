# %%
from google.colab import drive

# This will prompt you to authorize access to your Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
dataset = pd.read_csv("/content/drive/MyDrive/tour_logs_train.csv")

# %%
def fix_date(dataset):
  dataset["Show_DateTime"]= pd.to_datetime(dataset["Show_DateTime"],errors='coerce')
  if dataset["Show_DateTime"].isnull().any():
    dataset = dataset.dropna(subset=["Show_DateTime"])
  return dataset

# %%
dataset = fix_date(dataset)

# %%
def clean_price_simple(value):
  if pd.isna(value):
        return value
  text = str(value)
  clean_text = "".join(char for char in text if char.isdigit() or char == '.'or char=="£"or char=='€')
  return clean_text
dataset['Ticket_Price']= dataset["Ticket_Price"].apply(clean_price_simple)

def standardize_ticketprice(price):
  if pd.isna(price):
    if price <0 or price>100:
      return pd.NA
    else:
     price = price
     return price
  else:
    price_str = str(price)
    if '£' in price_str:

      price = float(price_str.replace('£',''))
      price = price * 1.27
      if price <0 or price>100:
        return pd.NA
      else:
        return price
    elif '€' in price_str:
      price = float(price_str.replace('€',''))
      price = price * 1.09

      if price <0 or price>100:
        return pd.NA
      else:
        return price
    else:
       try:
        return float(price)
       except :
        return pd.NA
dataset['Ticket_Price']=dataset['Ticket_Price'].apply(standardize_ticketprice)
dataset.dropna(inplace=True)

# %%
def plot_vol_energy(venue):
   sub = dataset[dataset['Venue_ID'] == venue]
   plt.scatter(sub['Volume_Level'], sub['Crowd_Energy'])
   plt.xlabel('Volume Level')
   plt.ylabel('Crowd Energy')
   plt.title(f'Volume vs Energy at {venue}')
   plt.show()
venues = dataset['Venue_ID'].unique()
for i in venues:
   plot_vol_energy(i)

# %%
def plot_vol_energy(venue):
   sub = dataset[dataset['Venue_ID'] == venue].copy()
   sub["Time"]= sub["Show_DateTime"].dt.hour
   plt.scatter(sub['Time'], sub['Crowd_Energy'])
   plt.xlabel('Show time')
   plt.ylabel('Crowd Energy')
   plt.title(f'Showtime vs Energy at {venue}')
   plt.show()
venues = dataset['Venue_ID'].unique()
for i in venues:
   plot_vol_energy(i)

# %%
dataset['Ticket_Price']= dataset["Ticket_Price"].apply(clean_price_simple)
dataset['Ticket_Price']=dataset['Ticket_Price'].apply(standardize_ticketprice)
dataset.dropna(inplace=True)
def plot_price_energy(venue):
  sub2 = dataset[dataset["Venue_ID"]==venue]
  plt.scatter(sub2["Ticket_Price"],sub2["Crowd_Energy"])
  plt.xlabel("Ticket_Price")
  plt.ylabel("Crowd_Energy")
  plt.title(f"Crowd energy vs ticket price at {venue}")
  plt.show()
venues = dataset['Venue_ID'].unique()
for i in venues:
   plot_price_energy(i)

# %%
plt.scatter(dataset["Moon_Phase"],dataset["Crowd_Energy"])
plt.xlabel("Moon Phase")
plt.ylabel("Crowd_Energy")
plt.title(f"Moon Phase vs ticket price at ")
plt.show()

# %%
dataset['Day_Name'] = dataset['Show_DateTime'].dt.day_name().copy()
daily_energy = dataset.groupby('Day_of_Week')['Crowd_Energy'].mean().sort_values()
print(daily_energy)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

daily_energy.plot(kind='bar', color='skyblue')
plt.title('Average Crowd Energy by Day of Week')
plt.xlabel('Day')
plt.ylabel('Average Energy Score')
plt.show()
# Out:
# Day_of_Week
# 4    54.639282
# 2    54.720601
# 1    57.572207
# 3    57.638901
# 5    60.112245
# 0    62.663300
# 6    67.065928
# Name: Crowd_Energy, dtype: float64

# %%
dataset.boxplot(column='Crowd_Energy', by='Weather', figsize=(10, 6))

plt.title('Weather vs Crowd Energy')

plt.ylabel('Crowd Energy')
plt.xlabel('Weather')
plt.show()

# %%
def fix_vol(df):
  df.loc[(df["Volume_Level"] < 0) | (df["Volume_Level"] > 100), "Volume_Level"] = pd.NA
  return df
def fix_energy(df):
  df.loc[(df["Crowd_Energy"] < 0) | (df["Crowd_Energy"] > 100), "Crowd_Energy"] = pd.NA
  return df
def fix_size(df):
  df.loc[df["Crowd_Size"] < 0, "Crowd_Size"] = pd.NA
  return df


dataset = fix_vol(dataset)
dataset = fix_energy(dataset)
dataset = fix_size(dataset)

dataset.dropna(inplace=True)

# %%
def feature_eng(df):
  df["Is_Weekend"]=df["Show_DateTime"].dt.dayofweek.isin([0,6]).astype(int)
  df["DayofWeek"]=df["Show_DateTime"].dt.day_name()
  df['Venue_Day_Combo'] = df['Venue_ID'] + "_" + df['Show_DateTime'].dt.day_name()

  months = df["Show_DateTime"].dt.month
  conditions = [
      months.isin([1, 2, 11, 12]),
      months.isin([3, 4]),
      months.isin([5, 6, 7])
  ]
  choices = ["Winter", "Spring", "Summer"]
  df["Season"] = np.select(conditions, choices, default="Autumn")
  df["Hour"]=df["Show_DateTime"].dt.hour
  df["Month"]=df["Show_DateTime"].dt.month

  return df


dataset['Show_DateTime'] = pd.to_datetime(dataset['Show_DateTime'], errors='coerce')
dataset.dropna(subset=['Show_DateTime'], inplace=True)
dataset = feature_eng(dataset)
column_to_move = dataset.pop("Crowd_Energy")
dataset["Crowd_Energy"] = column_to_move

dataset.drop(columns=["Show_DateTime", "Merch_Sales_Post_Show", "Gig_ID"], inplace=True)
print(dataset)
# Out:
#      Venue_ID  Day_of_Week  Volume_Level  Ticket_Price  Crowd_Size  \
# 0     V_Alpha            3           5.0         52.93       464.0
# 1      V_Beta            3           2.0         66.33       388.0
# 2     V_Delta            5           1.0         51.37       679.0
# 4     V_Delta            4           8.0         47.34       654.0
# 5     V_Alpha            2           3.0         69.63       320.0
# ...       ...          ...           ...           ...         ...
# 1988  V_Delta            0           6.0         49.11       583.0
# 1989  V_Delta            1           9.0         48.09       497.0
# 1990  V_Delta            4           8.0         24.36       550.0
# 1992   V_Beta            4           4.0         52.40       633.0
# 1999  V_Alpha            2           6.0         80.86       744.0
#
#       Opener_Rating Weather       Moon_Phase Band_Outfit   Day_Name  \
# 0                 2   Rainy  Waning Crescent     Leather   Thursday
# 1                 5   Clear         New Moon     Leather   Thursday
# 2                 1   Rainy  Waning Crescent       Denim   Saturday
# 4                 5  Cloudy        Full Moon     Spandex     Friday
# 5                 4  Cloudy    First Quarter       Denim  Wednesday
# ...             ...     ...              ...         ...        ...
# 1988              3  Cloudy         New Moon       Denim     Monday
# 1989              3   Clear    First Quarter     Leather    Tuesday
# 1990              2   Rainy   Waxing Gibbous     Spandex     Friday
# 1992              3   Clear   Waning Gibbous       Denim     Friday
# 1999              4   Clear        Full Moon     Spandex  Wednesday
#
#       Is_Weekend  DayofWeek    Venue_Day_Combo  Season  Hour  Month  \
# 0              0   Thursday   V_Alpha_Thursday  Spring    21      3
# 1              0   Thursday    V_Beta_Thursday  Autumn    22      9
# 2              0   Saturday   V_Delta_Saturday  Spring    15      3
# 4              0     Friday     V_Delta_Friday  Spring    17      4
# 5              0  Wednesday  V_Alpha_Wednesday  Autumn    20      9
# ...          ...        ...                ...     ...   ...    ...
# 1988           1     Monday     V_Delta_Monday  Summer    14      6
# 1989           0    Tuesday    V_Delta_Tuesday  Spring    23      4
# 1990           0     Friday     V_Delta_Friday  Autumn    18      8
# 1992           0     Friday      V_Beta_Friday  Spring    23      3
# 1999           0  Wednesday  V_Alpha_Wednesday  Autumn    19      8
#
#       Crowd_Energy
# 0            64.96
# 1            66.42
# 2            42.58
# 4            67.55
# 5            67.87
# ...            ...
# 1988         62.33
# 1989         72.15
# 1990         48.73
# 1992         59.05
# 1999         60.74
#
# [1355 rows x 17 columns]

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor


numeric_features = ['Ticket_Price', 'Crowd_Size', 'Day_of_Week', 'Volume_Level','Hour','Month','Opener_Rating']
categorical_features = ['Venue_ID', 'DayofWeek', 'Weather', 'Moon_Phase', 'Band_Outfit',"Season",'Venue_Day_Combo','Is_Weekend']


numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore')) ])


preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])


rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# %%
from sklearn.model_selection import GridSearchCV


param_grid = {
    'regressor__n_estimators': [50, 100, 200],
    'regressor__max_depth': [None, 10, 20],
    'regressor__min_samples_split': [2, 5]
}


search = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=1
)


print("Starting Grid Search for Random Forest...")
search.fit(x_train, y_train)


print("------------------------------------------------")
print(f"Best Parameters: {search.best_params_}")
print(f"Best RMSE Score: {-search.best_score_:.2f}")

best_rf_model = search.best_estimator_
# Out:
# Starting Grid Search for Random Forest...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# ------------------------------------------------
# Best Parameters: {'regressor__max_depth': 10, 'regressor__min_samples_split': 5, 'regressor__n_estimators': 200}
# Best RMSE Score: 12.40

# %%
test = pd.read_csv("/content/drive/MyDrive/tour_logs_test_input.csv")

# %%
test = fix_date(test)
test["Ticket_Price"] =  test["Ticket_Price"].apply(clean_price_simple)
test["Ticket_Price"]= test["Ticket_Price"].apply(standardize_ticketprice)
test = fix_vol(test)

test = fix_size(test)

test.dropna(inplace=True)
test= feature_eng(test)
test['Show_DateTime'] = pd.to_datetime(test['Show_DateTime'], errors='coerce')
test.dropna(subset=['Show_DateTime'], inplace=True)
test = feature_eng(test)

test.drop(columns=["Show_DateTime", "Merch_Sales_Post_Show", "Gig_ID"], inplace=True)

# %%
x_1 = dataset.iloc[:,:-1]
y_1 = dataset.iloc[:,-1]

# %%
from sklearn.metrics import mean_squared_error
_
predictions = best_rf_model.predict(x_1)
mse = mean_squared_error(y_1, predictions)
print(f"Final root Mean Squared Error: {mse**0.5}")
# Out:
# Final root Mean Squared Error: 8.934241945811639

# %%
import pandas as pd


prediction = search.predict(test)


id_list = [f"Gig_{i:04d}" for i in range(len(predictions))]


predictions_df = pd.DataFrame({
    'Gig_ID': id_list,
    'Crowd_Energy': predictions
})


predictions_df.to_csv('predictions.csv', index=False)


print(predictions_df.head())
# Out:
#      Gig_ID  Crowd_Energy
# 0  Gig_0000     61.903638
# 1  Gig_0001     52.410826
# 2  Gig_0002     48.984498
# 3  Gig_0003     65.608864
# 4  Gig_0004     61.616030

# %%
#BonusTask
df = dataset[dataset["Venue_ID"]=="V_Gamma"].copy()


df['Ticket_Price'] = df['Ticket_Price'].apply(clean_price_simple)
df['Ticket_Price'] = df['Ticket_Price'].apply(standardize_ticketprice)
df.dropna(subset=['Ticket_Price'], inplace=True)

# %%
print(df)
# Out:
#      Venue_ID  Day_of_Week  Volume_Level  Ticket_Price  Crowd_Size  \
# 6     V_Gamma            1           4.0       69.4563       107.0
# 8     V_Gamma            1           8.0       48.0472       539.0
# 12    V_Gamma            1          11.0       79.3100       441.0
# 13    V_Gamma            3           4.0       48.4000       694.0
# 16    V_Gamma            4           1.0       79.3900       339.0
# ...       ...          ...           ...           ...         ...
# 1958  V_Gamma            6           4.0       95.8000       594.0
# 1961  V_Gamma            1          10.0       76.2100       485.0
# 1966  V_Gamma            3          11.0       71.0000       643.0
# 1968  V_Gamma            4           9.0       52.5600       599.0
# 1970  V_Gamma            3           6.0       63.5200       272.0
#
#       Opener_Rating Weather       Moon_Phase Band_Outfit  Day_Name  \
# 6                 3   Clear         New Moon     Leather   Tuesday
# 8                 5   Clear         New Moon     Leather   Tuesday
# 12                3   Rainy   Waning Gibbous     Leather   Tuesday
# 13                3   Clear   Waning Gibbous     Spandex  Thursday
# 16                2   Clear    First Quarter     Spandex    Friday
# ...             ...     ...              ...         ...       ...
# 1958              3   Clear  Waning Crescent     Leather    Sunday
# 1961              3  Cloudy     Last Quarter       Denim   Tuesday
# 1966              3   Rainy  Waxing Crescent       Denim  Thursday
# 1968              3  Cloudy   Waning Gibbous     Leather    Friday
# 1970              1   Clear  Waxing Crescent     Leather  Thursday
#
#       Is_Weekend DayofWeek   Venue_Day_Combo  Season  Hour  Month  \
# 6              0   Tuesday   V_Gamma_Tuesday  Spring    19      4
# 8              0   Tuesday   V_Gamma_Tuesday  Spring    17      3
# 12             0   Tuesday   V_Gamma_Tuesday  Summer    20      6
# 13             0  Thursday  V_Gamma_Thursday  Summer    23      5
# 16             0    Friday    V_Gamma_Friday  Autumn    21      9
# ...          ...       ...               ...     ...   ...    ...
# 1958           1    Sunday    V_Gamma_Sunday  Spring    17      4
# 1961           0   Tuesday   V_Gamma_Tuesday  Autumn    16      8
# 1966           0  Thursday  V_Gamma_Thursday  Spring    18      3
# 1968           0    Friday    V_Gamma_Friday  Summer    17      6
# 1970           0  Thursday  V_Gamma_Thursday  Summer    19      6
#
#       Crowd_Energy
# 6            85.45
# 8            40.85
# 12           61.55
# 13           40.54
# 16           76.18
# ...            ...
# 1958         78.83
# 1961         75.43
# 1966         71.56
# 1968         46.92
# 1970         57.28
#
# [378 rows x 17 columns]

# %%
def pred_crowd(test_price): #assume attendance and ticket price are linearly related
  x,y=np.polyfit(df['Ticket_Price'],df['Crowd_Size'],1)
  return (x*test_price+y)

# %%
import numpy as np
def people_spend(df):
  base = 25

  spend = base*(1+0.0125*(df["Crowd_Energy"]-80))#
  return np.maximum(spend,5) #assuming people still spend bare minimum on drinks even if no energy

# %%
test_prices = np.arange(1, 100, 1)
test_df = pd.DataFrame({'Ticket_Price':test_prices})
test_df['Venue_ID'] = 'V_Gamma'
test_df['Day_of_Week'] = 5

test_df['Volume_Level'] = 5.0
test_df['Weather'] = 'Clear'
test_df['Moon_Phase'] = 'Full Moon'
test_df['Band_Outfit'] = 'Leather'
test_df['Is_Weekend']=0
test_df['Season']='Summer'
test_df['Hour']='18'
test_df['Month']=4
test_df['Venue_Day_Combo']='V_Gamma_Friday'
test_df['Opener_Rating']=7
test_df["DayofWeek"]='Friday'
test_df["Crowd_Size"]=test_df["Ticket_Price"].apply(pred_crowd)
test_df["Crowd_Energy"]=search.predict(test_df)
print(test_df)
# Out:
#     Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              1  V_Gamma            5           5.0   Clear  Full Moon
# 1              2  V_Gamma            5           5.0   Clear  Full Moon
# 2              3  V_Gamma            5           5.0   Clear  Full Moon
# 3              4  V_Gamma            5           5.0   Clear  Full Moon
# 4              5  V_Gamma            5           5.0   Clear  Full Moon
# ..           ...      ...          ...           ...     ...        ...
# 94            95  V_Gamma            5           5.0   Clear  Full Moon
# 95            96  V_Gamma            5           5.0   Clear  Full Moon
# 96            97  V_Gamma            5           5.0   Clear  Full Moon
# 97            98  V_Gamma            5           5.0   Clear  Full Moon
# 98            99  V_Gamma            5           5.0   Clear  Full Moon
#
#    Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  Opener_Rating  \
# 0      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 1      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 2      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 3      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 4      Leather           0  Summer   18      4  V_Gamma_Friday              7
# ..         ...         ...     ...  ...    ...             ...            ...
# 94     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 95     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 96     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 97     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 98     Leather           0  Summer   18      4  V_Gamma_Friday              7
#
#    DayofWeek  Crowd_Size  Crowd_Energy
# 0     Friday  594.105683     54.496605
# 1     Friday  593.392985     54.496605
# 2     Friday  592.680287     54.496605
# 3     Friday  591.967589     54.496605
# 4     Friday  591.254890     54.496605
# ..       ...         ...           ...
# 94    Friday  527.112058     86.970735
# 95    Friday  526.399360     86.908285
# 96    Friday  525.686661     86.908285
# 97    Friday  524.973963     87.111942
# 98    Friday  524.261265     87.188880
#
# [99 rows x 16 columns]

# %%
test_df["spend"]=people_spend(test_df)
print (test_df)
# Out:
#     Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              1  V_Gamma            5           5.0   Clear  Full Moon
# 1              2  V_Gamma            5           5.0   Clear  Full Moon
# 2              3  V_Gamma            5           5.0   Clear  Full Moon
# 3              4  V_Gamma            5           5.0   Clear  Full Moon
# 4              5  V_Gamma            5           5.0   Clear  Full Moon
# ..           ...      ...          ...           ...     ...        ...
# 94            95  V_Gamma            5           5.0   Clear  Full Moon
# 95            96  V_Gamma            5           5.0   Clear  Full Moon
# 96            97  V_Gamma            5           5.0   Clear  Full Moon
# 97            98  V_Gamma            5           5.0   Clear  Full Moon
# 98            99  V_Gamma            5           5.0   Clear  Full Moon
#
#    Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  Opener_Rating  \
# 0      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 1      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 2      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 3      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 4      Leather           0  Summer   18      4  V_Gamma_Friday              7
# ..         ...         ...     ...  ...    ...             ...            ...
# 94     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 95     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 96     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 97     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 98     Leather           0  Summer   18      4  V_Gamma_Friday              7
#
#    DayofWeek  Crowd_Size  Crowd_Energy      spend
# 0     Friday  594.105683     54.496605  17.030189
# 1     Friday  593.392985     54.496605  17.030189
# 2     Friday  592.680287     54.496605  17.030189
# 3     Friday  591.967589     54.496605  17.030189
# 4     Friday  591.254890     54.496605  17.030189
# ..       ...         ...           ...        ...
# 94    Friday  527.112058     86.970735  27.178355
# 95    Friday  526.399360     86.908285  27.158839
# 96    Friday  525.686661     86.908285  27.158839
# 97    Friday  524.973963     87.111942  27.222482
# 98    Friday  524.261265     87.188880  27.246525
#
# [99 rows x 17 columns]

# %% [markdown]
# profit = ticket price * attendance + (per person spend)* attendance - 5000-8*attendance

# %%
test_df["costs"]= 5000 +(8*test_df['Crowd_Size'])
test_df['earn']=test_df['spend']+ test_df["Crowd_Size"]*test_df["Ticket_Price"]
test_df["profit"]=test_df["earn"]-test_df["spend"]
print(test_df)
# Out:
#     Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              1  V_Gamma            5           5.0   Clear  Full Moon
# 1              2  V_Gamma            5           5.0   Clear  Full Moon
# 2              3  V_Gamma            5           5.0   Clear  Full Moon
# 3              4  V_Gamma            5           5.0   Clear  Full Moon
# 4              5  V_Gamma            5           5.0   Clear  Full Moon
# ..           ...      ...          ...           ...     ...        ...
# 94            95  V_Gamma            5           5.0   Clear  Full Moon
# 95            96  V_Gamma            5           5.0   Clear  Full Moon
# 96            97  V_Gamma            5           5.0   Clear  Full Moon
# 97            98  V_Gamma            5           5.0   Clear  Full Moon
# 98            99  V_Gamma            5           5.0   Clear  Full Moon
#
#    Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  Opener_Rating  \
# 0      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 1      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 2      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 3      Leather           0  Summer   18      4  V_Gamma_Friday              7
# 4      Leather           0  Summer   18      4  V_Gamma_Friday              7
# ..         ...         ...     ...  ...    ...             ...            ...
# 94     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 95     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 96     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 97     Leather           0  Summer   18      4  V_Gamma_Friday              7
# 98     Leather           0  Summer   18      4  V_Gamma_Friday              7
#
#    DayofWeek  Crowd_Size  Crowd_Energy      spend        costs          earn  \
# 0     Friday  594.105683     54.496605  17.030189  9752.845464    611.135872
# 1     Friday  593.392985     54.496605  17.030189  9747.143879   1203.816159
# 2     Friday  592.680287     54.496605  17.030189  9741.442294   1795.071049
# 3     Friday  591.967589     54.496605  17.030189  9735.740709   2384.900543
# 4     Friday  591.254890     54.496605  17.030189  9730.039124   2973.304641
# ..       ...         ...           ...        ...          ...           ...
# 94    Friday  527.112058     86.970735  27.178355  9216.896462  50102.823843
# 95    Friday  526.399360     86.908285  27.158839  9211.194877  50561.497364
# 96    Friday  525.686661     86.908285  27.158839  9205.493292  51018.765004
# 97    Friday  524.973963     87.111942  27.222482  9199.791707  51474.670891
# 98    Friday  524.261265     87.188880  27.246525  9194.090122  51929.111781
#
#           profit
# 0     594.105683
# 1    1186.785970
# 2    1778.040860
# 3    2367.870354
# 4    2956.274452
# ..           ...
# 94  50075.645489
# 95  50534.338525
# 96  50991.606165
# 97  51447.448409
# 98  51901.865256
#
# [99 rows x 20 columns]

# %%
plt.plot(test_df['Ticket_Price'], test_df['profit'], color='green', linewidth=2)

plt.title("Revenue Optimization Curve for V_Gamma")
plt.xlabel("Ticket Price ($)")
plt.ylabel("Projected Profit ($)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-3638532019.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
opt_index = test_df['profit'].idxmax()
opt_scenario = test_df.loc[opt_index]
opt_price = opt_scenario['Ticket_Price']
max_profit = opt_scenario['profit']
print(f"optimal price {opt_price}")
# Out:
# optimal price 99

# %% [markdown]
# Since the ticket price is limited between 1-100 the overall optimal ticket price does not lie in this range

# %%
test_prices = np.arange(100, 1200, 1)
test_df = pd.DataFrame({'Ticket_Price':test_prices})
test_df['Venue_ID'] = 'V_Gamma'
test_df['Day_of_Week'] = 5

test_df['Volume_Level'] = 5.0
test_df['Weather'] = 'Clear'
test_df['Moon_Phase'] = 'Full Moon'
test_df['Band_Outfit'] = 'Leather'
test_df['Is_Weekend']=0
test_df['Season']='Summer'
test_df['Hour']='18'
test_df['Month']=4
test_df['Venue_Day_Combo']='V_Gamma_Friday'
test_df['Opener_Rating']=7
test_df["DayofWeek"]='Friday'
test_df["Crowd_Size"]=test_df["Ticket_Price"].apply(pred_crowd)
test_df["Crowd_Energy"]=search.predict(test_df)
print(test_df)
# Out:
#       Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              100  V_Gamma            5           5.0   Clear  Full Moon
# 1              101  V_Gamma            5           5.0   Clear  Full Moon
# 2              102  V_Gamma            5           5.0   Clear  Full Moon
# 3              103  V_Gamma            5           5.0   Clear  Full Moon
# 4              104  V_Gamma            5           5.0   Clear  Full Moon
# ...            ...      ...          ...           ...     ...        ...
# 1095          1195  V_Gamma            5           5.0   Clear  Full Moon
# 1096          1196  V_Gamma            5           5.0   Clear  Full Moon
# 1097          1197  V_Gamma            5           5.0   Clear  Full Moon
# 1098          1198  V_Gamma            5           5.0   Clear  Full Moon
# 1099          1199  V_Gamma            5           5.0   Clear  Full Moon
#
#      Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  \
# 0        Leather           0  Summer   18      4  V_Gamma_Friday
# 1        Leather           0  Summer   18      4  V_Gamma_Friday
# 2        Leather           0  Summer   18      4  V_Gamma_Friday
# 3        Leather           0  Summer   18      4  V_Gamma_Friday
# 4        Leather           0  Summer   18      4  V_Gamma_Friday
# ...          ...         ...     ...  ...    ...             ...
# 1095     Leather           0  Summer   18      4  V_Gamma_Friday
# 1096     Leather           0  Summer   18      4  V_Gamma_Friday
# 1097     Leather           0  Summer   18      4  V_Gamma_Friday
# 1098     Leather           0  Summer   18      4  V_Gamma_Friday
# 1099     Leather           0  Summer   18      4  V_Gamma_Friday
#
#       Opener_Rating DayofWeek  Crowd_Size  Crowd_Energy
# 0                 7    Friday  523.548567     87.155105
# 1                 7    Friday  522.835869     87.155105
# 2                 7    Friday  522.123171     87.400451
# 3                 7    Friday  521.410473     87.400451
# 4                 7    Friday  520.697775     87.400451
# ...             ...       ...         ...           ...
# 1095              7    Friday -256.855897     86.036097
# 1096              7    Friday -257.568595     86.036097
# 1097              7    Friday -258.281293     86.036097
# 1098              7    Friday -258.993991     86.036097
# 1099              7    Friday -259.706690     86.036097
#
# [1100 rows x 16 columns]

# %%
test_df["spend"]=people_spend(test_df)
print (test_df)
# Out:
#       Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              100  V_Gamma            5           5.0   Clear  Full Moon
# 1              101  V_Gamma            5           5.0   Clear  Full Moon
# 2              102  V_Gamma            5           5.0   Clear  Full Moon
# 3              103  V_Gamma            5           5.0   Clear  Full Moon
# 4              104  V_Gamma            5           5.0   Clear  Full Moon
# ...            ...      ...          ...           ...     ...        ...
# 1095          1195  V_Gamma            5           5.0   Clear  Full Moon
# 1096          1196  V_Gamma            5           5.0   Clear  Full Moon
# 1097          1197  V_Gamma            5           5.0   Clear  Full Moon
# 1098          1198  V_Gamma            5           5.0   Clear  Full Moon
# 1099          1199  V_Gamma            5           5.0   Clear  Full Moon
#
#      Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  \
# 0        Leather           0  Summer   18      4  V_Gamma_Friday
# 1        Leather           0  Summer   18      4  V_Gamma_Friday
# 2        Leather           0  Summer   18      4  V_Gamma_Friday
# 3        Leather           0  Summer   18      4  V_Gamma_Friday
# 4        Leather           0  Summer   18      4  V_Gamma_Friday
# ...          ...         ...     ...  ...    ...             ...
# 1095     Leather           0  Summer   18      4  V_Gamma_Friday
# 1096     Leather           0  Summer   18      4  V_Gamma_Friday
# 1097     Leather           0  Summer   18      4  V_Gamma_Friday
# 1098     Leather           0  Summer   18      4  V_Gamma_Friday
# 1099     Leather           0  Summer   18      4  V_Gamma_Friday
#
#       Opener_Rating DayofWeek  Crowd_Size  Crowd_Energy        costs  \
# 0                 7    Friday  523.548567     87.155105  9188.388537
# 1                 7    Friday  522.835869     87.155105  9182.686951
# 2                 7    Friday  522.123171     87.400451  9176.985366
# 3                 7    Friday  521.410473     87.400451  9171.283781
# 4                 7    Friday  520.697775     87.400451  9165.582196
# ...             ...       ...         ...           ...          ...
# 1095              7    Friday -256.855897     86.036097  2945.152824
# 1096              7    Friday -257.568595     86.036097  2939.451239
# 1097              7    Friday -258.281293     86.036097  2933.749654
# 1098              7    Friday -258.993991     86.036097  2928.048069
# 1099              7    Friday -259.706690     86.036097  2922.346483
#
#           spend
# 0     27.235970
# 1     27.235970
# 2     27.312641
# 3     27.312641
# 4     27.312641
# ...         ...
# 1095  26.886280
# 1096  26.886280
# 1097  26.886280
# 1098  26.886280
# 1099  26.886280
#
# [1100 rows x 18 columns]

# %%
test_df["costs"]= 5000 +(8*test_df['Crowd_Size'])
test_df['earn']=test_df['spend']+ test_df["Crowd_Size"]*test_df["Ticket_Price"]
test_df["profit"]=test_df["earn"]-test_df["spend"]
print(test_df)
# Out:
#       Ticket_Price Venue_ID  Day_of_Week  Volume_Level Weather Moon_Phase  \
# 0              100  V_Gamma            5           5.0   Clear  Full Moon
# 1              101  V_Gamma            5           5.0   Clear  Full Moon
# 2              102  V_Gamma            5           5.0   Clear  Full Moon
# 3              103  V_Gamma            5           5.0   Clear  Full Moon
# 4              104  V_Gamma            5           5.0   Clear  Full Moon
# ...            ...      ...          ...           ...     ...        ...
# 1095          1195  V_Gamma            5           5.0   Clear  Full Moon
# 1096          1196  V_Gamma            5           5.0   Clear  Full Moon
# 1097          1197  V_Gamma            5           5.0   Clear  Full Moon
# 1098          1198  V_Gamma            5           5.0   Clear  Full Moon
# 1099          1199  V_Gamma            5           5.0   Clear  Full Moon
#
#      Band_Outfit  Is_Weekend  Season Hour  Month Venue_Day_Combo  \
# 0        Leather           0  Summer   18      4  V_Gamma_Friday
# 1        Leather           0  Summer   18      4  V_Gamma_Friday
# 2        Leather           0  Summer   18      4  V_Gamma_Friday
# 3        Leather           0  Summer   18      4  V_Gamma_Friday
# 4        Leather           0  Summer   18      4  V_Gamma_Friday
# ...          ...         ...     ...  ...    ...             ...
# 1095     Leather           0  Summer   18      4  V_Gamma_Friday
# 1096     Leather           0  Summer   18      4  V_Gamma_Friday
# 1097     Leather           0  Summer   18      4  V_Gamma_Friday
# 1098     Leather           0  Summer   18      4  V_Gamma_Friday
# 1099     Leather           0  Summer   18      4  V_Gamma_Friday
#
#       Opener_Rating DayofWeek  Crowd_Size  Crowd_Energy        costs  \
# 0                 7    Friday  523.548567     87.155105  9188.388537
# 1                 7    Friday  522.835869     87.155105  9182.686951
# 2                 7    Friday  522.123171     87.400451  9176.985366
# 3                 7    Friday  521.410473     87.400451  9171.283781
# 4                 7    Friday  520.697775     87.400451  9165.582196
# ...             ...       ...         ...           ...          ...
# 1095              7    Friday -256.855897     86.036097  2945.152824
# 1096              7    Friday -257.568595     86.036097  2939.451239
# 1097              7    Friday -258.281293     86.036097  2933.749654
# 1098              7    Friday -258.993991     86.036097  2928.048069
# 1099              7    Friday -259.706690     86.036097  2922.346483
#
#           spend           earn         profit
# 0     27.235970   52382.092678   52354.856707
# 1     27.235970   52833.658732   52806.422762
# 2     27.312641   53283.876062   53256.563421
# 3     27.312641   53732.591324   53705.278683
# 4     27.312641   54179.881190   54152.568549
# ...         ...            ...            ...
# 1095  26.886280 -306915.910634 -306942.796915
# 1096  26.886280 -308025.153508 -308052.039788
# 1097  26.886280 -309135.821777 -309162.708058
# 1098  26.886280 -310247.915443 -310274.801723
# 1099  26.886280 -311361.434505 -311388.320786
#
# [1100 rows x 20 columns]

# %%
plt.plot(test_df['Ticket_Price'], test_df['profit'], color='green', linewidth=2)

plt.title("Revenue Optimization Curve for V_Gamma")
plt.xlabel("Ticket Price ($)")
plt.ylabel("Projected Profit ($)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-3638532019.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
opt_index = test_df['profit'].idxmax()
opt_scenario = test_df.loc[opt_index]
opt_price = opt_scenario['Ticket_Price']
max_profit = opt_scenario['profit']
print(f"optimal price {opt_price}")
# Out:
# optimal price 417

# %%
from google.colab import files


files.download('predictions.csv')
